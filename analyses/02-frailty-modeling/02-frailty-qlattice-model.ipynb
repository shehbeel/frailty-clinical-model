# %% [markdown]
# # Frailty Risk Modeling using QLattice
# ### Author: Shehbeel Arif
# ### Purpose: To develop an ML or statistical model to determine a patient's frailty risk status based on the muscle gene expression data.

# %% [markdown]
# ---

# %% [markdown]
# ## Load libraries

# %%
# Library for data handling
import numpy as np
import pandas as pd

# Library for splitting data into Training and Testing datasets
from sklearn.model_selection import train_test_split

# QLattice library
import feyn

# Visualization library
import seaborn as sns
# Out:
# This version of feyn and the QLattice is available for academic, personal, and non-commercial use. By using the community version of this software you agree to the terms and conditions which can be found at `https://abzu.ai/eula`.

# %% [markdown]
# ## Data Preprocessing

# %%
# Load data
data_dir = '/Users/shehbeel/Documents/frailty-clinical-model/data/'
data_dir2 = '/Users/shehbeel/Documents/frailty-clinical-model/analyses/01-convert-ensembl-ids/results/'
meta = pd.read_csv(data_dir + 'GSE144304_meta.txt', delimiter='\t')
counts = pd.read_csv(data_dir2 + 'GSE144304_raw_counts_with_genes.csv', index_col='gene_symbol')

# Transpose counts
counts = counts.T
counts = counts.reset_index()

# Merge counts and meta data
data = pd.merge(meta, counts, left_on='sample_name', right_on='index').drop(['index'], axis=1)
data = data.set_index('sample_name')

# Convert target variable to boolean
#data['treatment'] = data['treatment'].map({'frail': True, 'fit': False, 'young':False}) 
data["frailty"] = data["frailty"].replace({"1":True, "0":False}).astype(bool)

# Drop gender for now
data = data.drop([#'gender', 
                  'condition'], axis=1)

# Sanity check
data
# Out:
#              gender  frailty  TSPAN6  TNMD  DPM1  SCYL3  C1orf112  FGR  CFH  \
# sample_name
# s301           male     True      99    20   284    101        19   15  252
# s302           male     True      54     3   381    127         7   39  113
# s303           male     True      44     2   303    123         9   16  147
# s304           male     True      59     3   306    146         1    6   92
# s305           male     True      52     0   402    103        10   31  115
# ...             ...      ...     ...   ...   ...    ...       ...  ...  ...
# s530         female    False      54     0   349    139         5    4   51
# s531           male    False      73     0   395    115        16   13  103
# s401           male    False      55     2   252     97         4   17   48
# s404           male    False      72     4   204     99        21   31  196
# s405         female    False      76    10   288     99         5   24  168
#
#              FUCA2  ...  MIR6787  MIR4793  MIR935  MIR5006  MIR4722  MIR92B  \
# sample_name         ...
# s301           120  ...        0        0       0        0        0       0
# s302           145  ...        0        0       0        0        0       0
# s303            82  ...        0        0       0        0        0       0
# s304            83  ...        0        0       0        1        0       0
# s305           137  ...        0        0       0        0        0       0
# ...            ...  ...      ...      ...     ...      ...      ...     ...
# s530            70  ...        0        0       0        0        0       0
# s531            69  ...        0        0       0        0        0       0
# s401            62  ...        0        0       0        1        0       0
# s404           115  ...        0        0       0        0        0       0
# s405           107  ...        0        0       0        0        0       0
#
#              MIR943  MIR7847  MIR6785  MIR4467
# sample_name
# s301              0        0        0        0
# s302              0        0        0        0
# s303              0        0        0        0
# s304              0        0        0        0
# s305              0        0        0        0
# ...             ...      ...      ...      ...
# s530              0        0        0        0
# s531              0        0        0        0
# s401              0        0        0        0
# s404              0        0        0        0
# s405              0        0        0        0
#
# [80 rows x 35837 columns]

# %%
# Split the data into training and testing set
seed = 42
train, test = train_test_split(data, test_size = 0.2, stratify=data["frailty"], random_state=seed)

# %% [markdown]
# ---

# %% [markdown]
# ## Perform QLattice

# %%
# Connect to QLattice
ql = feyn.QLattice()

# %%
ql.reset(random_seed=1)
# Out:
# Deprecation: The reset() function is deprecated. Instantiating a new feyn.QLattice() now achieves the same result.

# %%
# Set the variable to predict as output
models = ql.auto_run(train, 
                     output_name='frailty', 
                     kind='categorical', 
                     stypes=stypes,
                     criterion='bic', 
                     max_complexity=4
                     )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 # Set the variable to predict as output
# ----> 2 models = ql.auto_run(train,
#       3                      output_name='frailty',
#       4                      kind='categorical',
#       5                      stypes='',
#       6                      criterion='bic',
#       7                      max_complexity=4
#       8                      )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/feyn/_typings.py:51, in check_types.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#      46 verbose and print(
#      47     f"Validating def({param_name}: {expected_type}) - passed({param_value}: {type(param_value)})"
#      48 )
#      50 if not _validate_type(expected_type, param_value, verbose):
# ---> 51     _raise(param_name, expected_type)
#      52 if verbose:
#      53     print("---")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/feyn/_typings.py:250, in _raise(param_name, expected_type)
#     249 def _raise(param_name, expected_type):
# --> 250     raise TypeError(
#     251         f"{param_name} should be of type {expected_type}.".replace("typing.", "")
#     252     )
#
# TypeError: stypes should be of type Optional[Dict[str, str]].

# %%
data.dtypes
# Out:
# frailty    int64
# TSPAN6     int64
# TNMD       int64
# DPM1       int64
# SCYL3      int64
#            ...
# MIR92B     int64
# MIR943     int64
# MIR7847    int64
# MIR6785    int64
# MIR4467    int64
# Length: 35836, dtype: object
